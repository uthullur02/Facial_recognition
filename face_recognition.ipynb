# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\umasu\anaconda3\a\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.0.5)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\umasu\anaconda3\a\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\umasu\anaconda3\a\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: dm-tree in c:\users\umasu\anaconda3\a\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\umasu\anaconda3\a\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\umasu\anaconda3\a\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\umasu\anaconda3\a\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.0)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\umasu\anaconda3\a\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\umasu\anaconda3\a\lib\site-packages (from opencv-python) (1.26.4)

# %%
import cv2
import os
import random
import numpy as np
# !pip install matplotlib
from matplotlib import pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in c:\users\umasu\anaconda3\a\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\umasu\anaconda3\a\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\umasu\anaconda3\a\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\umasu\anaconda3\a\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\umasu\anaconda3\a\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\umasu\anaconda3\a\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\umasu\anaconda3\a\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf

# %%
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# %%
os.makedirs(POS_PATH)
os.makedirs(NEG_PATH)
os.makedirs(ANC_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 os.makedirs(POS_PATH)
#       2 os.makedirs(NEG_PATH)
#       3 os.makedirs(ANC_PATH)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data\\positive'

# %%
# !tar -xf lfw.tgz

# %%
import uuid

# %%
os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
# Out:
# 'data\\anchor\\1b411297-003e-11ef-aeb3-d9e5a4424ab3.jpg'

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened(): 
    ret, frame = cap.read()
   
    # Cut down frame to 250x250px
    frame = frame[120:120+250,200:200+250, :]
    
    # Collect anchors 
    if cv2.waitKey(1) & 0XFF == ord('a'):
        # Create the unique file path 
        imgname = os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out anchor image
        cv2.imwrite(imgname, frame)
    
    # Collect positives
    if cv2.waitKey(1) & 0XFF == ord('p'):
        # Create the unique file path 
        imgname = os.path.join(POS_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out positive image
        cv2.imwrite(imgname, frame)
    
    # Show image back to screen
    cv2.imshow('Image Collection', frame)
    
    # Breaking gracefully
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
        
# Release the webcam
cap.release()
# Close the image show frame
cv2.destroyAllWindows()

# %%
plt.imshow(frame)

# %%
def data_aug(img):
    data = []
    for i in range(9):
        img = tf.image.stateless_random_brightness(img, max_delta=0.02, seed=(1,2))
        img = tf.image.stateless_random_contrast(img, lower=0.6, upper=1, seed=(1,3))
        # img = tf.image.stateless_random_crop(img, size=(20,20,3), seed=(1,2))
        img = tf.image.stateless_random_flip_left_right(img, seed=(np.random.randint(100),np.random.randint(100)))
        img = tf.image.stateless_random_jpeg_quality(img, min_jpeg_quality=90, max_jpeg_quality=100, seed=(np.random.randint(100),np.random.randint(100)))
        img = tf.image.stateless_random_saturation(img, lower=0.9,upper=1, seed=(np.random.randint(100),np.random.randint(100)))
            
        data.append(img)
    
    return data

# %%
import os
import uuid

# %%
anchor = tf.data.Dataset.list_files(ANC_PATH+'\*.jpg').take(3000)
positive = tf.data.Dataset.list_files(POS_PATH+'\*.jpg').take(3000)
negative = tf.data.Dataset.list_files(NEG_PATH+'\*.jpg').take(3000)

# %%
dir_test = anchor.as_numpy_iterator()

# %%
print(dir_test.next())
# Out:
# b'data\\anchor\\663f52a4-fb4c-11ee-93a1-d9e5a4424ab3.jpg'

# %%
def preprocess(file_path):
    
    # Read in image from file path
    byte_img = tf.io.read_file(file_path)
    # Load in the image 
    img = tf.io.decode_jpeg(byte_img)
    
    # Preprocessing steps - resizing the image to be 100x100x3
    img = tf.image.resize(img, (100,100))
    # Scale image to be between 0 and 1 
    img = img / 255.0

    # Return image
    return img

# %%
img = preprocess('data\\anchor\\c3dc7ee2-fb39-11ee-bed1-d9e5a4424ab3.jpg'
)

# %%
positives = tf.data.Dataset.zip((anchor, positive, tf.data.Dataset.from_tensor_slices(tf.ones(len(anchor)))))
negatives = tf.data.Dataset.zip((anchor, negative, tf.data.Dataset.from_tensor_slices(tf.zeros(len(anchor)))))
data = positives.concatenate(negatives)

# %%
samples = data.as_numpy_iterator()

# %%
exampple = samples.next()

# %%
exampple
# Out:
# (b'data\\anchor\\9605ab13-fb55-11ee-9448-d9e5a4424ab3.jpg',
#  b'data\\positive\\dea094ba-fb51-11ee-a2de-d9e5a4424ab3.jpg',
#  1.0)

# %%
def preprocess_twin(input_img, validation_img, label):
    return(preprocess(input_img), preprocess(validation_img), label)

# %%
res = preprocess_twin(*exampple)

# %%
plt.imshow(res[1])

# %%
data = data.map(preprocess_twin)
data = data.cache()
data = data.shuffle(buffer_size=10000)

# %%
train_data = data.take(round(len(data)*.7))
train_data = train_data.batch(16)
train_data = train_data.prefetch(8)

# %%
test_data = data.skip(round(len(data)*.7))
test_data = test_data.take(round(len(data)*.3))
test_data = test_data.batch(16)
test_data = test_data.prefetch(8)

# %%
inp = Input(shape=(100,100,3), name='input_image')

# %%
c1 = Conv2D(64, (10,10), activation='relu')(inp)
m1 = MaxPooling2D(64, (2,2), padding='same')(c1)
c2 = Conv2D(128, (7,7), activation='relu')(m1)
m2 = MaxPooling2D(64, (2,2), padding='same')(c2)
c3 = Conv2D(128, (4,4), activation='relu')(m2)
m3 = MaxPooling2D(64, (2,2), padding='same')(c3)
c4 = Conv2D(256, (4,4), activation='relu')(m3)
f1 = Flatten()(c4)
d1 = Dense(4096, activation='sigmoid')(f1)
mod = Model(inputs=[inp], outputs=[d1], name='embedding')

# %%
def make_embedding(): 
    inp = Input(shape=(100,100,3), name='input_image')
    
    # First block
    c1 = Conv2D(64, (10,10), activation='relu')(inp)
    m1 = MaxPooling2D(64, (2,2), padding='same')(c1)
    
    # Second block
    c2 = Conv2D(128, (7,7), activation='relu')(m1)
    m2 = MaxPooling2D(64, (2,2), padding='same')(c2)
    
    # Third block 
    c3 = Conv2D(128, (4,4), activation='relu')(m2)
    m3 = MaxPooling2D(64, (2,2), padding='same')(c3)
    
    # Final embedding block
    c4 = Conv2D(256, (4,4), activation='relu')(m3)
    f1 = Flatten()(c4)
    d1 = Dense(4096, activation='sigmoid')(f1)
    
    
    return Model(inputs=[inp], outputs=[d1], name='embedding')

# %%
embedding = make_embedding()

# %%
class L1Dist(Layer):
    
    # Init method - inheritance
    def __init__(self, **kwargs):
        super().__init__()
       
    # Magic happens here - similarity calculation
    def call(self, input_embedding, validation_embedding):
        inp_embedding = tf.convert_to_tensor(input_embedding)
        validation_embedding = tf.convert_to_tensor(validation_embedding)
        input_embedding = tf.squeeze(input_embedding, axis=0)  # Remove potential first dimension
        validation_embedding = tf.squeeze(validation_embedding, axis=0)
        return tf.math.abs(input_embedding - validation_embedding)
l1 = L1Dist()

# %%
input_image = Input(name='input_img', shape=(100,100,3))
validation_image = Input(name='validation_img', shape=(100,100,3))

# %%
inp_embedding = embedding(input_image)
val_embedding = embedding(validation_image)

# %%
siamese_layer = L1Dist()

# %%
distances=siamese_layer(inp_embedding, val_embedding)
# Out:
# WARNING:tensorflow:From C:\Users\umasu\anaconda3\a\Lib\site-packages\keras\src\backend\tensorflow\core.py:174: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
classifier = Dense(1, activation='sigmoid')(distances)

# %%
siamese_network = Model(inputs=[input_image, validation_image], outputs=classifier, name='SiameseNetwork')
siamese_network.summary()
# Out:
# Model: "SiameseNetwork"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_img (InputLayer)        │ (None, 100, 100, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ validation_img (InputLayer)   │ (None, 100, 100, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Functional)        │ (None, 4096)              │      38,960,448 │ input_img[0][0],           │
# │                               │                           │                 │ validation_img[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ l1_dist_1 (L1Dist)            │ (None, 4096)              │               0 │ embedding[0][0],           │
# │                               │                           │                 │ embedding[1][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 1)                 │           4,097 │ l1_dist_1[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 38,964,545 (148.64 MB)
#  Trainable params: 38,964,545 (148.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def make_siamese_model(): 
    
    # Anchor image input in the network
    input_image = Input(name='input_img', shape=(100,100,3))
    
    # Validation image in the network 
    validation_image = Input(name='validation_img', shape=(100,100,3))
    
    # Combine siamese distance components
    siamese_layer = L1Dist()
    siamese_layer._name = 'distance'
    distances = siamese_layer(embedding(input_image), embedding(validation_image))
    
    # Classification layer 
    classifier = Dense(1, activation='sigmoid')(distances)
    
    return Model(inputs=[input_image, validation_image], outputs=classifier, name='SiameseNetwork')
siamese_model = make_siamese_model()

# %%
binary_cross_loss = tf.losses.BinaryCrossentropy()

# %%
opt = tf.keras.optimizers.Adam(1e-4)

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, 'ckpt')

# %%
class TrainState(tf.Module):
  def __init__(self, siamese_model, optimizer):
    super(TrainState, self).__init__()
    self.siamese_model = siamese_model
    self.optimizer = optimizer

checkpoint = tf.train.Checkpoint(train_state=TrainState(siamese_model, opt))

# %%
test_batch = train_data.as_numpy_iterator()
batch_1 = test_batch.next()
X = batch_1[:2]
y = batch_1[2]

# %%
@tf.function
def train_step(batch):
    
    # Record all of our operations 
    with tf.GradientTape() as tape:     
        # Get anchor and positive/negative image
        X = batch[:2]
        # Get label
        y = batch[2]
        
        # Forward pass
        yhat = siamese_model(X, training=True)
        # Calculate loss
        loss = binary_cross_loss(y, yhat)
    print(loss)
        
    # Calculate gradients
    grad = tape.gradient(loss, siamese_model.trainable_variables)
    
    # Calculate updated weights and apply to siamese model
    opt.apply_gradients(zip(grad, siamese_model.trainable_variables))
        
    # Return loss
    return loss

# %%
from tensorflow.keras.metrics import Precision, Recall

# %%
def train(data, EPOCHS):
    # Loop through epochs
    for epoch in range(1, EPOCHS+1):
        print('\n Epoch {}/{}'.format(epoch, EPOCHS))
        progbar = tf.keras.utils.Progbar(len(data))
        
        # Creating a metric object 
        r = Recall()
        p = Precision()
        
        # Loop through each batch
        for idx, batch in enumerate(data):
            # Run train step here
            loss = train_step(batch)
            yhat = siamese_model.predict(batch[:2])
            r.update_state(batch[2], yhat)
            p.update_state(batch[2], yhat) 
            progbar.update(idx+1)
        print(loss.numpy(), r.result().numpy(), p.result().numpy())
        
        # Save checkpoints
        if epoch % 10 == 0: 
            checkpoint.save(file_prefix=checkpoint_prefix)

# %%
EPOCHS = 50

# %%
train(train_data, EPOCHS)
# Out:
#  Epoch 1/50
# Tensor("binary_crossentropy/truediv:0", shape=(), dtype=float32)
# Tensor("binary_crossentropy/truediv:0", shape=(), dtype=float32)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 887ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/stepTensor("binary_crossentropy/truediv:0", shape=(), dtype=float32)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step
# 0.6602398 1.0 0.73333335
#
#  Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.35193005 1.0 0.7419355
#
#  Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.2677404 1.0 0.9019608
#
#  Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.007977791 1.0 0.97727275
#
#  Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.007531131 1.0 1.0
#
#  Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.003951686 0.97727275 1.0
#
#  Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00030895922 1.0 1.0
#
#  Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.0045678597 1.0 1.0
#
#  Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.0012199213 1.0 1.0
#
#  Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00026652447 1.0 1.0
#
#  Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.000106302214 1.0 1.0
#
#  Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00020471326 1.0 1.0
#
#  Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.001408201 1.0 1.0
#
#  Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00014220893 1.0 1.0
#
#  Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 4.431173e-05 1.0 1.0
#
#  Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00037001667 1.0 1.0
#
#  Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.0002671394 1.0 1.0
#
#  Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 4.94114e-05 1.0 1.0
#
#  Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 1.2338572e-05 1.0 1.0
#
#  Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00042193185 1.0 1.0
#
#  Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.000117485404 1.0 1.0
#
#  Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 5.485473e-05 1.0 1.0
#
#  Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.0030412113 1.0 1.0
#
#  Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00013990307 1.0 1.0
#
#  Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 9.334994e-05 1.0 1.0
#
#  Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 8.7555905e-05 1.0 1.0
#
#  Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00013793774 1.0 1.0
#
#  Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 3.977315e-05 1.0 1.0
#
#  Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00016289073 1.0 1.0
#
#  Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.000108053944 1.0 1.0
#
#  Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 4.308009e-05 1.0 1.0
#
#  Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 9.627129e-06 1.0 1.0
#
#  Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 1.9561885e-05 1.0 1.0
#
#  Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 2.3156423e-05 1.0 1.0
#
#  Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00010376628 1.0 1.0
#
#  Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 3.929789e-05 1.0 1.0
#
#  Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00097475125 1.0 1.0
#
#  Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.0009048054 1.0 1.0
#
#  Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 6.6518433e-06 1.0 1.0
#
#  Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 1.8023193e-05 1.0 1.0
#
#  Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 2.1737476e-05 1.0 1.0
#
#  Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 0.00012720522 1.0 1.0
#
#  Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 3.0521183e-05 1.0 1.0
#
#  Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 1.0046547e-05 1.0 1.0
#
#  Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 6.00938e-05 1.0 1.0
#
#  Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 3.7974853e-05 1.0 1.0
#
#  Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 1.6082427e-05 1.0 1.0
#
#  Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 4.380389e-05 1.0 1.0
#
#  Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 2.6111142e-05 1.0 1.0
#
#  Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 3.4392974e-06 1.0 1.0

# %%
from tensorflow.keras.metrics import Precision, Recall

# %%
test_input, test_val, y_true = test_data.as_numpy_iterator().next()

# %%
y_hat = siamese_model.predict([test_input, test_val])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step

# %%
m = Recall()

# Calculating the recall value 
m.update_state(y_true, y_hat)

# Return Recall Result
m.result().numpy()
# Out:
# 1.0

# %%
m = Precision()

# Calculating the recall value 
m.update_state(y_true, y_hat)

# Return Recall Result
m.result().numpy()
# Out:
# 1.0

# %%
r = Recall()
p = Precision()

for test_input, test_val, y_true in test_data.as_numpy_iterator():
    yhat = siamese_model.predict([test_input, test_val])
    r.update_state(y_true, yhat)
    p.update_state(y_true,yhat) 

print(r.result().numpy(), p.result().numpy())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1.0 1.0

# %%
# Set plot size 
plt.figure(figsize=(10,8))

# Set first subplot
plt.subplot(1,2,1)
plt.imshow(test_input[0])

# Set second subplot
plt.subplot(1,2,2)
plt.imshow(test_val[0])

# Renders cleanly
plt.show()

# %%
L1Dist
# Out:
# __main__.L1Dist

# %%
siamese_model.predict([test_input, test_val])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# array([[5.8545411e-05],
#        [9.9999893e-01],
#        [9.9999905e-01],
#        [9.9999326e-01],
#        [1.0071611e-04],
#        [1.2524314e-06]], dtype=float32)

# %%
siamese_model.summary()
# Out:
# Model: "SiameseNetwork"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_img (InputLayer)        │ (None, 100, 100, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ validation_img (InputLayer)   │ (None, 100, 100, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Functional)        │ (None, 4096)              │      38,960,448 │ input_img[0][0],           │
# │                               │                           │                 │ validation_img[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ l1_dist_2 (L1Dist)            │ (None, 4096)              │               0 │ embedding[2][0],           │
# │                               │                           │                 │ embedding[3][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 1)                 │           4,097 │ l1_dist_2[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 38,964,545 (148.64 MB)
#  Trainable params: 38,964,545 (148.64 MB)
#  Non-trainable params: 0 (0.00 B)
